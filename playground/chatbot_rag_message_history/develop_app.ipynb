# %%
import streamlit as st

st.title("Hello, Streamlit!")
st.write("This is your first Streamlit app.")
# Out:
# 2025-08-03 15:56:06.435 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 15:56:06.810
# ...
#   command:
#
#     streamlit run c:\Users\sagnik\anaconda3\envs\GenAI\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-08-03 15:56:06.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 15:56:06.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 15:56:06.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 15:56:06.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 15:56:06.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
